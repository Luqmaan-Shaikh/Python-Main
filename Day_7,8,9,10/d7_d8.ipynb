# %% [markdown]
# # What are Infix to Postfix
# - Infix Expression: Operators are written between operands.
# 1. Example: a + b or a + b * c
# 1. Humans find this easy to read, but computers find it harder to evaluate directly.
#
# - Postfix: perators come after operands.
# 1. Example: ab+ or abc*+
# 2. Computers find this easier to evaluate because there’s no need for parentheses or operator precedence.

# %%
def precedence(op):
    if op == '+' or op == '-':
        return 1
    if op == '*' or op == '/':
        return 2
    if op == '^':
        return 3
    return 0

def infix_to_postfix(expression):
    stack = []      # Stack to hold operators
    output = []     # List for the result

    for char in expression:
        if char.isalnum():  # If character is a letter or number (operand)
            output.append(char)
        elif char == '(':   # If character is '(' push to stack
            stack.append(char)
        elif char == ')':   # If character is ')', pop until '('
            while stack and stack[-1] != '(':
                output.append(stack.pop())
            stack.pop()     # Remove '(' from stack
        else:               # If character is an operator
            while (stack and precedence(char) <= precedence(stack[-1])):
                if stack[-1] == '(':
                    break
                output.append(stack.pop())
            stack.append(char)

    # Pop any remaining operators from the stack
    while stack:
        output.append(stack.pop())

    return ''.join(output)


def infix_to_prefix(expression):
    expression = expression[::-1]
    expression = ''.join(['(' if c == ')' else ')' if c == '(' else c for c in expression])
    postfix = infix_to_postfix(expression)
    return postfix[::-1]

infix = "a+b*(c-d)"
print("Infix Expression:   ", infix)
print("Postfix Expression: ", infix_to_postfix(infix))
print("Prefix Expression:  ", infix_to_prefix(infix))
# Out:
# Infix Expression:    a+b*(c-d)
# Postfix Expression:  abcd-*+
# Prefix Expression:   +a*b-cd

# %%
# def precedence(op):
#     # Returns precedence of the operator
#     if op == '+' or op == '-':
#         return 1
#     if op == '*' or op == '/':
#         return 2
#     if op == '^':
#         return 3
#     return 0

# def infix_to_postfix(expression):
#     stack = []      # Stack to hold operators
#     output = []     # List for the result

#     for char in expression:
#         if char.isalnum():  # Operand
#             output.append(char)
#         elif char == '(':
#             stack.append(char)
#         elif char == ')':
#             while stack and stack[-1] != '(':
#                 output.append(stack.pop())
#             stack.pop()     # Remove '('
#         else:  # Operator
#             while (stack and precedence(char) <= precedence(stack[-1])):
#                 if stack[-1] == '(':
#                     break
#                 output.append(stack.pop())
#             stack.append(char)

#     while stack:
#         output.append(stack.pop())

#     return ''.join(output)

# def infix_to_prefix(expression):
#     # Step 1: Reverse the infix expression
#     expression = expression[::-1]
#     # Step 2: Swap '(' with ')' and vice versa
#     expression = ''.join(['(' if c == ')' else ')' if c == '(' else c for c in expression])
#     # Step 3: Get postfix of the modified expression
#     postfix = infix_to_postfix(expression)
#     # Step 4: Reverse postfix to get prefix
#     return postfix[::-1]

# # Example usage with user input
# infix = input("Enter an infix expression: ")
# print("Infix Expression:   ", infix)
# print("Postfix Expression: ", infix_to_postfix(infix))
# print("Prefix Expression:  ", infix_to_prefix(infix))
# Out:
# Infix Expression:    (a+b)*c
# Postfix Expression:  ab+c*
# Prefix Expression:   *+abc

# %% [markdown]
# - Given a string s containing just the characters '(', ')', '{', '}', '[' and ']', determine if the input string is valid.
# 2. Open brackets must be closed by the same type of brackets.
# 3. Open brackets must be closed in the correct order.
# 4. Every close bracket has a corresponding open bracket of the same type.

# %% [markdown]
# # leetcode qp
# 1. 1047
# 2. 739
# 3.

# %%
def is_valid(s):
    stack = []
    bracket_map = {')': '(', '}': '{', '[':']'}
    
    for char in s:
        if char in bracket_map.values():
            stack.append(char)
        elif char in bracket_map:
            if not stack or stack[-1] != bracket_map[char]:
                return False
            stack.pop()

    return not stack

s=input("Enter the string")
if is_valid(s):
    print("The string is now valid")
else:
    print("the string is not valid")
# Out:
# The string is now valid

# %%
class Solution:
    def removeDuplicates(self, s: str) -> str:
        stack = []
        for char in s:
            if stack and stack[-1] == char:
                stack.pop()
            else:
                stack.append(char)
        return ''.join(stack)

sol=Solution()
s = input("enter the setring")
print("final staring is: ", sol.removeDuplicates(s))
# Out:
# final staring is:

# %%
def dailyTemperatures(temperatures):
    n = len(temperatures)
    answer = [0] * n
    stack = []  
    for i, temp in enumerate(temperatures):
        while stack and temp > temperatures[stack[-1]]:
            prev_index = stack.pop()
            answer[prev_index] = i - prev_index  
        stack.append(i)
    return answer


temps = list(map(int, input("Enter temperatures separated by space: ").split()))
print("Days to wait for a warmer temperature:", dailyTemperatures(temps))
# Out:
# Days to wait for a warmer temperature: []

# %%
# class Queue:
#     def __init__(self, maxsize):
#         self.maxsize = maxsize
#         self.myqueue = []
        
#     def enqueue(self, value):
#         if len(self.myqueue) < self.maxsize:
#             self.myqueue.append(value)
#             print('Element enqueued successfully!')
#         else:
#             print('Queue is full!')
            
#     def displayqueue(self):
#         print(self.myqueue)
        
#     def isempty(self):
#         return len(self.myqueue) == 0
        
#     def dequeue(self):
#         if self.isempty():
#             print("Queue is empty")
#         else:
#             dequeued_element = self.myqueue[0]
#             self.myqueue = self.myqueue[1:]
#             print(dequeued_element)
    
#     def peek(self):
#         if self.isempty():
#             print("Queue is empty")
#         else:
#             print(self.myqueue[0])
            
#     def delete(self):
#         self.myqueue = []
#         print('Queue deleted successfully!')

# maxsize = int(input("Enter the size of the queue:"))
# obj = Queue(maxsize)
# print('Queue created successfully!')

# while True:
#     print('1. Enqueue')
#     print('2. Dequeue')
#     print('3. Peek')
#     print('4. Is Empty')
#     print('5. Delete')
#     print('6. Display')
#     print('7. Exit')
#     choice = int(input("Enter your choice:"))
#     if choice == 1:
#         value = int(input("Enter the value for the queue:"))
#         obj.enqueue(value)
#     elif choice == 2:
#         obj.dequeue()
#     elif choice == 3:
#         obj.peek()
#     elif choice == 4:
#         print(obj.isempty())
#     elif choice == 5:
#         obj.delete()
#     elif choice == 6:
#         obj.displayqueue()
#     elif choice == 7:
#         sys.exit()
#     else:
#         print('Invalid choice!')

# %%
# class cqueue:
#     def __init__(self, size):
#         self.size = size
#         self.front = -1
#         self.rear = -1
#         self.queue = [None] * size
        
#     def enqueue(self, data):
#         if (self.rear+1)%self.size == self.front:
#             print("Queue is full")
#         if self.front == -1:
#             self.rear = 0
#             self.front = 0
#         else:
#             self.rear = (self.rear + 1) % self.size
#         self.queue[self.rear] = data
#         print("enqueued: ")
        
#     def dequeue(self):
#         if self.front == -1:
#             print("Queue is empty")
#             return
        
#         self.queue[self.front] = None
        
#         if self.front == self.rear:
#             self.front = -1
#             self.rear = -1
#         else:
#             self.front = (self.front + 1) % self.size
            
#     def display(self):
#         if self.front == -1:
#             print("Queue is empty")
#             return
#         i = self.front
#         while True:
#             print(self.queue[i], end=' ')
#             if i == self.rear:
#                 break
#             i = (i + 1) % self.size
#         print()

# %%
class cqueue:
    def __init__(self, size):
        self.size = size
        self.front = -1
        self.rear = -1
        self.queue = [None] * size

    def enqueue(self, data):
        if (self.rear + 1) % self.size == self.front:
            print("Queue is full")
            return
        if self.front == -1:
            self.rear = 0
            self.front = 0
        else:
            self.rear = (self.rear + 1) % self.size
        self.queue[self.rear] = data
        print("enqueued:", data)

    def dequeue(self):
        if self.front == -1:
            print("Queue is empty")
            return
        removed = self.queue[self.front]
        self.queue[self.front] = None
        if self.front == self.rear:
            self.front = -1
            self.rear = -1
        else:
            self.front = (self.front + 1) % self.size
        print("dequeued:", removed)

    def display(self):
        if self.front == -1:
            print("Queue is empty")
            return
        i = self.front
        print("Queue contents:", end=' ')
        while True:
            print(self.queue[i], end=' ')
            if i == self.rear:
                break
            i = (i + 1) % self.size
        print()

    def is_empty(self):
        return self.front == -1

    def is_full(self):
        return (self.rear + 1) % self.size == self.front

    def peek(self):
        if self.front == -1:
            print("Queue is empty")
            return None
        print("Front element:", self.queue[self.front])
        return self.queue[self.front]


cq = cqueue(5)
cq.enqueue(10)
cq.enqueue(15)
cq.enqueue(20)
cq.enqueue(25)
cq.enqueue(30)
cq.dequeue()
cq.display()
cq.peek()
# Out:
# enqueued: 10
# enqueued: 15
# enqueued: 20
# enqueued: 25
# enqueued: 30
# dequeued: 10
# Queue contents: 15 20 25 30
# Front element: 15
# 15

# %%
# class pq:
#     def __init__(self):
#         self.queue = []
        
#     def enqueue(self,pr, data):
#         self.queue.append((pr, data))
#         self.queue.sort(reverse=True)
        
#         def dequeue(self):
#             if not self.queue:
#                 print("Queue is empty")
#                 return None
#             return self.queue.pop()[1]
#             print("Dequeued:", data)
#         def display(self):

# %%
class QueueStack:
    def __init__(self):
        self.stack_in = []
        self.stack_out = []

    def enqueue(self, x):
        self.stack_in.append(x)
        print("Enqueued:", x)

    def dequeue(self):
        if not self.stack_out:
            while self.stack_in:
                self.stack_out.append(self.stack_in.pop())
        if not self.stack_out:
            print("Queue is empty")
            return None
        val = self.stack_out.pop()
        print("Dequeued:", val)
        return val
    
q = QueueStack()
q.enqueue(12)
q.enqueue(13)
q.enqueue(81)
q.dequeue()
# Out:
# Enqueued: 12
# Enqueued: 13
# Enqueued: 81
# Dequeued: 12
# 12

# %%
#Implement stack using queue

class stack_using_queue():
    
    def __init__(self):
        self.que1 = []
        self.que2 = []
        
    def push(self, x):
        self.que2.append(x)
        while self.que1:
            self.que2.append(self.que1.pop())
        self.que1, self.que2 = self.que2,self.que1
        print("pushed", x)
        
    def pop(self):
        if not self.que1:
            print("stack is emtpy")
            return None
        val = self.que1.pop(0)
        print("pop", val)
        return val
    
    def is_empty(self):
        return len(self.que1)
    
s = stack_using_queue()
s.push(20)
s.push(40)
s.push(55)
s.pop()
s.is_empty()
# Out:
# pushed 20
# pushed 40
# pushed 55
# pop 55
# 2

# %% [markdown]
# # Tree
# >A tree is a hierarchical data structure in which elements are connected in a parent-child relationship.
# - Each element is called a node
# - The top node is called the root
# - Each node can have zero or more children.
# - Nodes with no children are called leaves.
# - There are no cycles in a tree.
#
# 1. Subtree has:
#    - Has Ancestors
#    - has descendants
#    - Uncle Nodes
#    - Degree
#    - Leaf Nodes
#
# 2. Binary tree has:
#    - Has Levels
#    - has Height
#    - Requires Every Nodes to be considered "Complete Binary Tree"
#
# - strict tree has:
#    - Has Levels
#    - has Height
#    - Requires Every Nodes to be considered "Complete Binary Tree"

# %%
import queue


class Node:
    def __init__(self, data):
        self.data = data
        self.right: 'Node | None' = None
        self.left: 'Node | None' = None

root = Node(9)
root.left = Node(22)
root.right = Node(55)
root.left.left = Node(78)
root.left.right = Node(99)
root.right.right = Node(33)
root.right.left = Node(68)

def bfs(root):
    if not root:
        return
    queue = [root]
    while queue:
        node = queue.pop(0)
        print(node.data, end = ' ')
        if node.left:
            queue.append(node.left)
        if node.right:
            queue.append(node.right)

print("Bfs:")
bfs(root)
# Out:
# Bfs:
# 9 22 55 78 99 68 33

# %%
# # inorder: left, root, right
# # preorder: root, left, right
# # Postorder: left, right, root

# class Node:
#     def __init__(self, data):
#         self.data = data
#         self.right: 'Node | None' = None
#         self.left: 'Node | None' = None

# class BST:
#     def __init__(self):
#         self.root = None
        
#     def insert(self, data):
#         if not self.root:
#             self.root = Node(data)
#         else:
#             self._insert(self.root, data)
    
#     def _insert(self, node, data):
#         if data < node.data:
#             if node.left is None:
#                 node.left = Node(data)
#             else:
#                 self. _insert(node.left, data)
#         elif data > node.data:
#             if node.right is None:
#                 node.right = Node(data)
#             else:
#                 self._insert(node.left, data)

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

class BST:
    def __init__(self):
        self.root = None

    def insert(self, data):
        if not self.root:
            self.root = Node(data)
        else:
            self._insert(self.root, data)

    def _insert(self, node, data):
        if data < node.data:
            if node.left is None:
                node.left = Node(data)
            else:
                self._insert(node.left, data)
        elif data > node.data:
            if node.right is None:
                node.right = Node(data)
            else:
                self._insert(node.right, data)

    def inorder(self, node):
        if node:
            self.inorder(node.left)
            print(node.data, end=' ')
            self.inorder(node.right)

    def preorder(self, node):
        if node:
            print(node.data, end=' ')
            self.preorder(node.left)
            self.preorder(node.right)

    def postorder(self, node):
        if node:
            self.postorder(node.left)
            self.postorder(node.right)
            print(node.data, end=' ')

bst = BST()
values = [50, 30, 70, 20, 40, 60, 80]
for v in values:
    bst.insert(v)

print("Inorder (sorted):")
bst.inorder(bst.root)
print("\nPreorder:")
bst.preorder(bst.root)
print("\nPostorder:")
bst.postorder(bst.root)
# inorder: left, root, right
# preorder: root, left, right
# Postorder: left, right, root
# Out:
# Inorder (sorted):
# 20 30 40 50 60 70 80
# Preorder:
# 50 30 20 40 70 60 80
# Postorder:
# 20 40 30 60 80 70 50

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.right: 'Node | None' = None
        self.left: 'Node | None' = None
        
def reverse_node(node):
    if node:
        reverse_node(node.right)
        print(node.data, end = ' ')
        reverse_node(node.left)
        
root = Node(10)
root.left = Node(5)
root.right = Node(15)
root.left.left = Node(2)
root.left.right = Node(7)
root.right.left = Node(12)
root.right.right = Node(20)

print("Reverse inorder traversal (right, root, left):")
reverse_node(root)
# Out:
# Reverse inorder traversal (right, root, left):
# 20 15 12 10 7 5 2

# %%
# class Node:
#     def __init__(self, data):
#         self.data = data
#         self.left = None
#         self.right = None

# class BST:
#     def __init__(self):
#         self.root = None

#     def insert(self, data):
#         if not self.root:
#             self.root = Node(data)
#         else:
#             self._insert(self.root, data)

#     def _insert(self, node, data):
#         if data < node.data:
#             if node.left is None:
#                 node.left = Node(data)
#             else:
#                 self._insert(node.left, data)
#         elif data > node.data:
#             if node.right is None:
#                 node.right = Node(data)
#             else:
#                 self._insert(node.right, data)

#     def inorder(self, node):
#         if node:
#             self.inorder(node.left)
#             print(node.data, end=' ')
#             self.inorder(node.right)

#     def preorder(self, node):
#         if node:
#             print(node.data, end=' ')
#             self.preorder(node.left)
#             self.preorder(node.right)

#     def postorder(self, node):
#         if node:
#             self.postorder(node.left)
#             self.postorder(node.right)
#             print(node.data, end=' ')


#     def delete(self, node,key):
#         if node is None:
#             return node
#         if key < node.data:
#             node.left = self.delete(node.left, key)
#         elif key > node.data:
#             node.right = self.delete(node.right, key)
#         else:
            
#             if node.left is None:
#                 temp = node.right
#                 node = None
#                 return temp
#             elif node.right is None:
#                 temp = node.left
#                 node = None
#                 return temp
#             temp = self._minval(node, right)
#             node.data = temp.data
#             node.right = self.delete(node, right)
#         return node

#     def _minval(self, node):
#             current = node
#             while current.left is not None:
#                 current = current.left
#             return current



# bst = BST()
# values = [50, 30, 70, 20, 40, 60, 80]
# for v in values:
#     bst.insert(v)

# print("Inorder (sorted):")
# bst.inorder(bst.root)
# print("\nPreorder:")
# bst.preorder(bst.root)
# print("\nPostorder:")
# bst.postorder(bst.root)

# key = 70
# bst.root = bst.delete(bst.root, key)
# print(f"\n\nAfter deleting {key}:")
# print("Inorder (sorted):")
# bst.inorder(bst.root)
# print("\nPreorder:")
# bst.preorder(bst.root)
# print("\nPostorder:")
# bst.postorder(bst.root)


# def reverse_node(node):
#     if node:
#         reverse_node(node.right)
#         print(node.data, end = ' ')
#         reverse_node(node.left)
        
# print("\nReverse order traversal")
# reverse_node(bst.root)

# %%
class Node:
    def __init__(self, data):
        self.root = None
        self.data = data
        self.left = None
        self.right = None

class BST:
    def __init__(self):
        self.root = None

    def insert(self, data):
        if not self.root:
            self.root = Node(data)
        else:
            self._insert(self.root, data)

    def _insert(self, node, data):
        if data < node.data:
            if node.left is None:
                node.left = Node(data)
            else:
                self._insert(node.left, data)
        elif data > node.data:
            if node.right is None:
                node.right = Node(data)
            else:
                self._insert(node.right, data)

    def inorder(self, node):
        if node:
            self.inorder(node.left)
            print(node.data, end=' ')
            self.inorder(node.right)

    def preorder(self, node):
        if node:
            print(node.data, end=' ')
            self.preorder(node.left)
            self.preorder(node.right)

    def postorder(self, node):
        if node:
            self.postorder(node.left)
            self.postorder(node.right)
            print(node.data, end=' ')

    # def Height(self, node):
    #     if node is None:
    #         return -1
    #     else:
    #         left_height = self.Height(node, left)
    #         right_height = self.Height(node, right)
    #         return 1 + max(left_height, right_height)

bst = BST()
values = [50, 30, 70, 20, 40, 60, 80]
for v in values:
    bst.insert(v)

print("Inorder (sorted):")
bst.inorder(bst.root)
print("\nPreorder:")
bst.preorder(bst.root)
print("\nPostorder:")
bst.postorder(bst.root)

# print("\nHeight of BST:", bst.Height(bst.root))
# Out:
# Inorder (sorted):
# 20 30 40 50 60 70 80
# Preorder:
# 50 30 20 40 70 60 80
# Postorder:
# 20 40 30 60 80 70 50
